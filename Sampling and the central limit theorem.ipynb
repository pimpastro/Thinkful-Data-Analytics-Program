# %% [markdown]
# Reproduce the pop1 and pop2 populations and samples using numpy's binomial function.
#
# Specifically, create two binomially distributed populations with n equal to 10 and size equal to 10000.
#
# The p-value of pop1 should be 0.2 and the p-value of pop2 should be 0.5.
#
# Using a sample size of 100, calculate the means and standard deviations of your samples.

# %%
import numpy as np
import pandas as pd
import scipy
import matplotlib.pyplot as plt
from scipy.stats import ttest_ind
# %matplotlib inline

# %%
# Creating two binomially distributed populations with n equal to 10 and size equal to 10000.
# The p-value of pop1 = 0.2 and the p-value of pop2 = 0.5.
pop1 = np.random.binomial(10, 0.2, 10000)
pop2 = np.random.binomial(10,0.5, 10000)

# %%
# Let’s make histograms for the two groups. 

plt.hist(pop1, alpha=0.5, label='Population 1') 
plt.hist(pop2, alpha=0.5, label='Population 2') 
plt.legend(loc='upper right') 
plt.show()

# %%
# Creating a samples
sample1 = np.random.choice(pop1, 100, replace=True)
sample2 = np.random.choice(pop2, 100, replace=True)

mean_sample1 = np.mean(sample1)
st_dev_sample1 = np.std(sample1)


plt.hist(sample1, alpha=0.5, label='sample 1') 
plt.hist(sample2, alpha=0.5, label='sample 2') 

mean_sample2 = np.mean(sample2)
st_dev_sample2 = np.std(sample2)

plt.axvline(x=mean_sample1, linestyle='solid', color='black')
plt.axvline(x=mean_sample1+st_dev_sample1, linestyle='dashed', color='black')
plt.axvline(x=mean_sample1-st_dev_sample1, linestyle='dashed', color='black')

plt.axvline(x=mean_sample2, linestyle='solid', color='blue')
plt.axvline(x=mean_sample2+st_dev_sample2, linestyle='dashed', color='blue')
plt.axvline(x=mean_sample2-st_dev_sample2, linestyle='dashed', color='blue')

plt.legend(loc='upper right') 
plt.show()

# Calculate the means and standard deviations of our samples.

print(sample1.mean())
print(sample2.mean())
print(sample1.std())
print(sample2.std())

# Compute the difference between the two sample means.
diff=sample2.mean( ) -sample1.mean()
print(diff)

print(ttest_ind(sample2, sample1, equal_var=False))
# Out:
# 1.89
# 5.17
# 1.31829435256319
# 1.6616558007000126
# 3.2800000000000002
# Ttest_indResult(statistic=15.38627337313875, pvalue=4.000252653947596e-35)

# %% [markdown]
# 1) Increase the size of your samples from 100 to 1000, then calculate the means and standard deviations for your new samples and create histograms for each. Repeat this again, decreasing the size of your samples to 20. What values change, and what remain the same?

# %% [markdown]
# If I increase the size of my sample from 100 to 1000 I can expect:
# a) The sample distribution will look more like normal destribution
# b) the p-value will decrease

# %%
# Creating a new samples with n = 1000
sample1_1 = np.random.choice(pop1, 1000, replace=True)
sample2_1 = np.random.choice(pop2, 1000, replace=True)

mean_sample1_1 = np.mean(sample1_1)
st_dev_sample1_1 = np.std(sample1_1)

plt.axvline(x=mean_sample1_1, linestyle='solid', color='black')
plt.axvline(x=mean_sample1_1+st_dev_sample1_1, linestyle='dashed', color='black')
plt.axvline(x=mean_sample1_1-st_dev_sample1_1, linestyle='dashed', color='black')

mean2_1 = np.mean(sample2_1)
st_dev2_1 = np.std(sample2_1)

plt.axvline(x=mean2_1, linestyle='solid', color='blue')
plt.axvline(x=mean2_1+st_dev2_1, linestyle='dashed', color='blue')
plt.axvline(x=mean2_1-st_dev2_1, linestyle='dashed', color='blue')

plt.hist(sample1_1, alpha=0.5, label='sample 1_1') 
plt.hist(sample2_1, alpha=0.5, label='sample 2_1') 
plt.legend(loc='upper right') 
plt.show()

print('sample1_1.mean:', sample1_1.mean())
print('sample2_1.mean:', sample2_1.mean())
print('st_dev1_1:', sample1_1.std())
print('st_dev2_1:', sample2_1.std())
# Compute the difference between the two sample means.
diff_1=sample2_1.mean( ) -sample1_1.mean()
print(diff_1)

print(ttest_ind(sample2_1, sample1_1, equal_var=False))
# Out:
# sample1_1.mean: 1.969
# sample2_1.mean: 4.885
# st_dev1_1: 1.2704483460574068
# st_dev2_1: 1.5867498227508958
# 2.9159999999999995
# Ttest_indResult(statistic=45.34191749315803, pvalue=3.344027817820863e-305)

# %%
# Creating a new samples with n = 20
sample1_2 = np.random.choice(pop1, 20, replace=True)
sample2_2 = np.random.choice(pop2, 20, replace=True)

mean_sample1_2 = np.mean(sample1_1)
st_dev_sample1_2 = np.std(sample1_1)

plt.axvline(x=mean_sample1_2, linestyle='solid', color='black')
plt.axvline(x=mean_sample1_2+st_dev_sample1_2, linestyle='dashed', color='black')
plt.axvline(x=mean_sample1_2-st_dev_sample1_2, linestyle='dashed', color='black')

mean2_2 = np.mean(sample2_2)
st_dev2_2 = np.std(sample2_2)

plt.axvline(x=mean2_2, linestyle='solid', color='blue')
plt.axvline(x=mean2_2+st_dev2_2, linestyle='dashed', color='blue')
plt.axvline(x=mean2_2-st_dev2_2, linestyle='dashed', color='blue')

plt.hist(sample1_2, alpha=0.5, label='sample 1_2') 
plt.hist(sample2_2, alpha=0.5, label='sample 2_2') 
plt.legend(loc='upper right') 
plt.show()

print('sample1_2.mean:', sample1_2.mean())
print('sample2_2.mean:', sample2_2.mean())
print('st_dev1_2:', sample1_1.std())
print('st_dev2_2:', sample2_1.std())
# Compute the difference between the two sample means.
diff_2 =sample2_2.mean( ) - sample1_2.mean()
print(diff_2)

print(ttest_ind(sample2_2, sample1_2, equal_var=False))
# Out:
# sample1_2.mean: 2.15
# sample2_2.mean: 4.35
# st_dev1_2: 1.2704483460574068
# st_dev2_2: 1.5867498227508958
# 2.1999999999999997
# Ttest_indResult(statistic=5.486480929985086, pvalue=5.11168701205976e-06)

# %% [markdown]
# 2) Change the probability value (p in the NumPy documentation) for pop1 to 0.3, then take new samples and compute the t-statistic and p-value.

# %%
pop3 = np.random.binomial(10, 0.3, 10000)
pop4 = np.random.binomial(10,0.5, 10000) 
plt.hist(pop3, alpha=0.5, label='Population 1') 
plt.hist(pop4, alpha=0.5, label='Population 2') 
plt.legend(loc='upper right') 
plt.show()

# %%
sample3 = np.random.choice(pop3, 100, replace=True)
sample4 = np.random.choice(pop4, 100, replace=True)

plt.hist(sample3, alpha=0.5, label='sample 1') 
plt.hist(sample4, alpha=0.5, label='sample 2') 
plt.legend(loc='upper right') 
plt.show()

# %%
print(sample3.mean())
print(sample4.mean())
print(sample3.std())
print(sample4.std())

# Compute the difference between the two sample means.
diff=sample4.mean( ) -sample3.mean()
print(diff)
# Out:
# 2.97
# 4.86
# 1.284172885557081
# 1.5938632312717425
# 1.8900000000000001

# %%
from scipy.stats import ttest_ind
print(ttest_ind(sample4, sample3, equal_var=False))
# Out:
# Ttest_indResult(statistic=9.187520139612728, pvalue=7.149120605152061e-17)

# %% [markdown]
# Then change the probability value p for group 1 to 0.4, and do it again. What changes, and why?

# %%
pop3_1 = np.random.binomial(10, 0.4, 10000)
pop4_1 = np.random.binomial(10,0.5, 10000) 
plt.hist(pop3_1, alpha=0.5, label='Population 1') 
plt.hist(pop4_1, alpha=0.5, label='Population 2') 
plt.legend(loc='upper right') 
plt.show()

# %%
sample3_1 = np.random.choice(pop3_1, 100, replace=True)
sample4_1 = np.random.choice(pop4_1, 100, replace=True)

plt.hist(sample3_1, alpha=0.5, label='sample 1') 
plt.hist(sample4_1, alpha=0.5, label='sample 2') 
plt.legend(loc='upper right') 
plt.show()

# %%
print(sample3_1.mean())
print(sample4_1.mean())
print(sample3_1.std())
print(sample4_1.std())

# Compute the difference between the two sample means.
diff=sample4_1.mean( ) -sample3_1.mean()
print(diff)
# Out:
# 3.97
# 4.74
# 1.596590116466966
# 1.3972830779766854
# 0.77

# %%
from scipy.stats import ttest_ind
print(ttest_ind(sample4_1, sample3_1, equal_var=False))
# Out:
# Ttest_indResult(statistic=3.6110183488172467, pvalue=0.0003880402215083285)

# %% [markdown]
# Change the distribution of your populations from binomial to a distribution of your choice. Do the sample mean values still accurately represent the population values?

# %%
# The Central Limit Theorem says the statistics should still work as long as the sample size is large enough, 
# no matter what distribution is chosen

# %%
population_1 = np.random.exponential(scale=1.0, size=100)
population_2 = np.random.exponential(scale=1.0, size=100)
plt.hist(population_1, alpha=0.5, label='Exponential Population 1')
plt.hist(population_2, alpha=0.2, label='Exponential Population 2')  


plt.legend(loc='upper right') 
plt.show()

# %%
sample_exp_1 = np.random.choice(population_1, 100, replace=True)
sample_exp_2 = np.random.choice(population_2, 100, replace=True)

mean_sample1_exp_1 = np.mean(sample_exp_1)
st_dev_sample1_exp_1 = np.std(sample_exp_1)

plt.axvline(x=mean_sample1_exp_1, linestyle='solid', color='black')
plt.axvline(x=mean_sample1_exp_1+st_dev_sample1_exp_1, linestyle='dashed', color='black')
plt.axvline(x=mean_sample1_exp_1-st_dev_sample1_exp_1, linestyle='dashed', color='black')

mean_sample_exp_2 = np.mean(sample_exp_2)
st_dev2_sample_exp_2 = np.std(sample_exp_2)

plt.axvline(x=mean_sample_exp_2, linestyle='solid', color='blue')
plt.axvline(x=mean_sample_exp_2+st_dev2_2, linestyle='dashed', color='blue')
plt.axvline(x=mean_sample_exp_2-st_dev2_2, linestyle='dashed', color='blue')

plt.hist(sample_exp_1, alpha=0.5, label='sample_exp_1') 
plt.hist(sample_exp_2, alpha=0.5, label='sample_exp_2') 
plt.legend(loc='upper right') 
plt.show()

print('mean_sample_exp_1.mean:', sample_exp_1.mean())
print('mean_sample_exp_2.mean:', sample_exp_2.mean())
print('st_dev2_sample_exp_1:', sample_exp_1.std())
print('st_dev2_sample_exp_2:', sample_exp_2.std())
# Compute the difference between the two sample means.
diff_2 =sample_exp_2.mean( ) - sample_exp_1.mean()
print(diff_2)

print(ttest_ind(sample_exp_2, sample_exp_1, equal_var=False))
# Out:
# mean_sample_exp_1.mean: 0.9546698144226391
# mean_sample_exp_2.mean: 0.8872762926521552
# st_dev2_sample_exp_1: 1.2769430662017172
# st_dev2_sample_exp_2: 0.8583082465897826
# -0.06739352177048386
# Ttest_indResult(statistic=-0.4358241007973385, pvalue=0.6635067638562536)
