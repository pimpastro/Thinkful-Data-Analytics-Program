# %%
import pandas as pd

# %%
data_path = ('Desktop/Thinkful/amazon_cells_labelled.txt')
amz = pd.read_csv(data_path, delimiter= '\t', header=None)

#Score is either 1 (for positive) or 0 (for negative)
amz.columns = ['review', 'score']

# %%
amz
# Out:
#                                                 review  score
# 0    So there is no way for me to plug it in here i...      0
# 1                          Good case, Excellent value.      1
# 2                               Great for the jawbone.      1
# 3    Tied to charger for conversations lasting more...      0
# 4                                    The mic is great.      1
# 5    I have to jiggle the plug to get it to line up...      0
# 6    If you have several dozen or several hundred c...      0
# 7          If you are Razr owner...you must have this!      1
# 8                  Needless to say, I wasted my money.      0
# 9                     What a waste of money and time!.      0
# 10                     And the sound quality is great.      1
# 11   He was very impressed when going from the orig...      1
# 12   If the two were seperated by a mere 5+ ft I st...      0
# 13                            Very good quality though      1
# ...

# %%
#Another feature option would be if the message is all uppercase. That seems kind of spammy doesn't it?
#amz['review'] = amz.review.str.lower()

# %%
#The words chosen below are simply intuited as possibly having something to point on 1 (for positive)
keywords = ['good', 'great', 'expected', 'recommended', 'happy', 'excellent', 'wow', 'fast']

for key in keywords:
    # Note that we add spaces around the key so that we're getting the word,
    # not just pattern matching.
    amz[str(key)] = amz.review.str.contains((' ' + str(key) + ' '), case=False)
    amz[str(key)] = amz.review.str.contains((str(key) + ' '), case=False)
    amz[str(key)] = amz.review.str.contains((' ' + str(key)), case=False)

# %%
amz['allcaps'] = amz.review.str.isupper()

# %%
amz
# Out:
#                                                 review  score   good  great  \
# 0                             Wow... Loved this place.      1  False  False
# 1                                   Crust is not good.      0   True  False
# 2            Not tasty and the texture was just nasty.      0  False  False
# 3    Stopped by during the late May bank holiday of...      1  False  False
# 4    The selection on the menu was great and so wer...      1  False   True
# 5       Now I am getting angry and I want my damn pho.      0  False  False
# 6                Honeslty it didn't taste THAT fresh.)      0  False  False
# 7    The potatoes were like rubber and you could te...      0  False  False
# 8                            The fries were great too.      1  False   True
# 9                                       A great touch.      1  False   True
# 10                            Service was very prompt.      1  False  False
# ...

# %%
amz['score'] = (amz['score'] == 1)

# %%
amz
# Out:
#                                                 review  score   good  great  \
# 0                             Wow... Loved this place.   True  False  False
# 1                                   Crust is not good.  False   True  False
# 2            Not tasty and the texture was just nasty.  False  False  False
# 3    Stopped by during the late May bank holiday of...   True  False  False
# 4    The selection on the menu was great and so wer...   True  False   True
# 5       Now I am getting angry and I want my damn pho.  False  False  False
# 6                Honeslty it didn't taste THAT fresh.)  False  False  False
# 7    The potatoes were like rubber and you could te...  False  False  False
# 8                            The fries were great too.   True  False   True
# 9                                       A great touch.   True  False   True
# 10                            Service was very prompt.   True  False  False
# ...

# %%
import seaborn as sns

# %%
sns.heatmap(amz.corr())

# %%
data = amz[keywords + ['allcaps']]
target = amz['score']

# %%
# Our data is binary / boolean, so we're importing the Bernoulli classifier.
from sklearn.naive_bayes import BernoulliNB
# Instantiate our model and store it in a new variable.
bnb = BernoulliNB()
# Fit our model to the data.
bnb.fit(data, target)
# Classify, storing the result in a new variable.
y_pred = bnb.predict(data)

# Display our results.
print("Number of mislabeled points out of a total {} points : {}".format(
    data.shape[0],
    (target != y_pred).sum()
))
# Out:
# Number of mislabeled points out of a total 1000 points : 392
